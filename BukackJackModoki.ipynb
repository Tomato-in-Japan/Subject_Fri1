# %% [markdown]
# <a href="https://colab.research.google.com/github/Tomato-in-Japan/Subject_Fri1/blob/Homeworks/BukackJackModoki.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s=[]
import random
symbol_list=['C','D','S','H']
card_list=[]
card_draw1 = []
card_draw2 = []
print("Aは1として扱う")
for symbol in symbol_list:
  for number in range(1,14):
    if number ==1:
      card = symbol + 'A'
    elif number ==11:
      card = symbol + 'J'
    elif number ==12:
      card = symbol + 'Q'
    elif number ==13:
      card = symbol + 'K'
    else:
      card = symbol + str(number)
    card_list.append(card)
random.shuffle(card_list)
for i in range(2):
 drawn=card_list.pop(0)
 card_draw1.append(drawn)
for i in range(2):
 drawn=card_list.pop(0)
 card_draw2.append(drawn)
print("Dearer Card")
for number in range(1):
  s=card_draw1[number]
  if s[0]==symbol_list[2]:
    a='Spade'
  elif s[0]==symbol_list[0]:
     a='Clover'
  elif s[0]==symbol_list[1]:
     a='Diamond'
  elif s[0]==symbol_list[3]:
    a='Heart'
  print('Card {} is {} {}'.format(number+1,a,s[1:]))
print("Player Card")
for number in range(2):
  s=card_draw2[number]
  if s[0]==symbol_list[2]:
    a='Spade'
  elif s[0]==symbol_list[0]:
     a='Clover'
  elif s[0]==symbol_list[1]:
     a='Diamond'
  elif s[0]==symbol_list[3]:
    a='Heart'
  print('Card {} is {} {}'.format(number+1,a,s[1:]))
while True :
  x=0
  sum2=0
  for i in range(len(card_draw2)):
    a1=card_draw2[i]
    a=a1[1:]
    if a == "K":
      a = 10
    elif a == "A":
      a =1
    elif a == "J":
      a =10
    elif a == "Q":
      a = 10
    sum2=sum2+int(a)
  if sum2 >= 22 :
    x=2
    break;
  if x==0:
    y = int(input("Hit(Draw) : 0 , Stand(result) : 1\n"))
    if y == 1:
      print("Player Card")
      for number in range(len(card_draw2)):
        s=card_draw2[number]
        if s[0]==symbol_list[2]:
          a='Spade'
        elif s[0]==symbol_list[0]:
          a='Clover'
        elif s[0]==symbol_list[1]:
          a='Diamond'
        elif s[0]==symbol_list[3]:
          a='Heart'
        print('Card {} is {} {}'.format(number+1,a,s[1:]))
      break;
    else:
      drawn=card_list.pop(0)
      card_draw2.append(drawn)
    print("Player Card")
    for number in range(len(card_draw2)):
      s=card_draw2[number]
      if s[0]==symbol_list[2]:
        a='Spade'
      elif s[0]==symbol_list[0]:
        a='Clover'
      elif s[0]==symbol_list[1]:
        a='Diamond'
      elif s[0]==symbol_list[3]:
        a='Heart'
      print('Card {} is {} {}'.format(number+1,a,s[1:]))
while True :
  sum1=0
  for i in range(len(card_draw1)):
    a1=card_draw1[i]
    a=a1[1:]
    if a == "K":
      a = 10
    elif a == "A":
      a =1
    elif a == "J":
      a =10
    elif a == "Q":
      a = 10
    sum1=sum1+int(a)
  if sum1 >= 17 :
    break;
  elif sum1 <=16 :
      drawn=card_list.pop(0)
      card_draw1.append(drawn)
print("Dealer Card")
for number in range(len(card_draw1)):
  s=card_draw1[number]
  if s[0]==symbol_list[2]:
    a='Spade'
  elif s[0]==symbol_list[0]:
     a='Clover'
  elif s[0]==symbol_list[1]:
     a='Diamond'
  elif s[0]==symbol_list[3]:
    a='Heart'
  print('Card {} is {} {}'.format(number+1,a,s[1:]))
print("Dealer Sum : ",sum1)
print("Player Sum : ",sum2)
if sum1 >=22 :
  if sum2>=22:
    print("Draw")
  else:
    print("You win !")
else:
  if sum2 >=22:
    print("You lose.")
  else:
    if sum1 == sum2:
      if len(card_draw2) == len(card_draw1):
        print("Draw")
      elif len(card_draw2) < len(card_draw1):
        print("You win !")
      elif len(card_draw2) > len(card_draw1):
        print("You lose.")
    elif sum1 < sum2 :
      print("You win !")
    else:
      print("You lose.")
# Out:
# Aは1として扱う
# Dearer Card
# Card 1 is Clover 2
# Player Card
# Card 1 is Diamond 6
# Card 2 is Clover 6
# Stand(Draw) : 0 , Hit(result) : 1
# 0
# Player Card
# Card 1 is Diamond 6
# Card 2 is Clover 6
# Card 3 is Diamond 8
# Stand(Draw) : 0 , Hit(result) : 1
# 1
# Player Card
# Card 1 is Diamond 6
# Card 2 is Clover 6
# Card 3 is Diamond 8
# Dealer Card
# Card 1 is Clover 2
# Card 2 is Diamond Q
# Card 3 is Heart 10
# Dealer Sum :  22
# Player Sum :  20
# You win !
